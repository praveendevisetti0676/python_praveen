# %%
student = {

"name": "Rahul",

"age": 22,

"course": "Data Science",

"city": "Bangalore"

}

# print every key and value
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# name: Rahul
# age: 22
# course: Data Science
# city: Bangalore
