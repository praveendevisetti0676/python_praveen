# %%
# Python Nested Dictionary Challenge
employee = {
    "name": "Amit",
    "department": "Engineering",
    "skills": {
        "language": "Python",
        "database": "PostgreSQL",
        "cloud": "AWS"
    },
    "salary": 80000
}
#Print employee name
print("Employee Name:", employee["name"])
#Print department
print("Department:", employee["department"])
#Print complete skills dictionary
print("Skills:", employee["skills"])
#Print programming language
print("Programming Language:", employee["skills"]["language"])  
#Print database
print("Database:", employee["skills"]["database"])
#Print cloud technology
print("Cloud Technology:", employee["skills"]["cloud"])
#Change "Python" to "Python + JavaScript"
employee["skills"]["language"] = "Python + JavaScript"
print("Updated Skills:", employee["skills"])
#Add another skill under the skills dictionary
print("Adding a new skill: DevOps")
employee["skills"]["DevOps"] = "Docker"
print("Updated Skills:", employee["skills"])    
#Change salary
employee["salary"] = 90000
print("Updated Salary:", employee["salary"])
# Add "experience": 3
employee["experience"] = 3
print("Updated Employee Dictionary:", employee)
# Out:
# Employee Name: Amit
# Department: Engineering
# Skills: {'language': 'Python', 'database': 'PostgreSQL', 'cloud': 'AWS'}
# Programming Language: Python
# Database: PostgreSQL
# Cloud Technology: AWS
# Updated Skills: {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS'}
# Adding a new skill: DevOps
# Updated Skills: {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS', 'DevOps': 'Docker'}
# Updated Salary: 90000
# Updated Employee Dictionary: {'name': 'Amit', 'department': 'Engineering', 'skills': {'language': 'Python + JavaScript', 'database': 'PostgreSQL', 'cloud': 'AWS', 'DevOps': 'Docker'}, 'salary': 90000, 'experience': 3}
