# %%
name = input ("Enter your name")
age= int(input("Enter your age:"))
city= input("Enter your city:")
college_name= input("Enter your college name:")
company_name= input("Enter your company name:")
currenttopic= input("Enter your current topic:")
yearsofexp = float(input("Enter your years of experience:"))
likepython= bool(input("Do you like python? (True/False):"))
exp_sal= float(input("Enter your expected salary after learning python:"))


print("Yourname", name)
print("Your age", age)
print("Your city", city)
print("Your college name", college_name)
print("Your company name", company_name)
print("Your current topic", currenttopic)
print("Your years of experience", yearsofexp)
print("Do you like python?", likepython)
print("Your expected salary", exp_sal)

print (f"Datatype of name is {type(name)}")
print (f"Datatype of age is {type(age)}")
print (f"Datatype of city is {type(city)}")
print (f"Datatype of college_name is {type(college_name)}")
print (f"Datatype of company_name is {type(company_name)}")
print (f"Datatype of currenttopic is {type(currenttopic)}")
print (f"Datatype of yearsofexp is {type(yearsofexp)}")
print (f"Datatype of likepython is {type(likepython)}")
print (f"Datatype of exp_sal is {type(exp_sal)}")
# Out:
# Yourname Praveen
# Your age 50
# Your city Hyderabad
# Your college name HPC
# Your company name Acentra
# Your current topic Variables
# Your years of experience 23.0
# Do you like python? True
# Your expected salary 56987.0
# Datatype of name is <class 'str'>
# Datatype of age is <class 'int'>
# Datatype of city is <class 'str'>
# Datatype of college_name is <class 'str'>
# Datatype of company_name is <class 'str'>
# Datatype of currenttopic is <class 'str'>
# Datatype of yearsofexp is <class 'float'>
# Datatype of likepython is <class 'bool'>
# Datatype of exp_sal is <class 'float'>
