# %%
products = {
    "Laptop": 55000,
    "Phone": 30000,
    "Headphones": 2000,
    "Mouse": 700,
    "Keyboard": 1500
}
# print products with price greater than 2000
for product, price in products.items():
    if price > 2000:
        print(product, ":", price) 
        print("product who cost is more than 2000 is", product, "and its price is", price)
# Out:
# Laptop : 55000
# product who cost is more than 2000 is Laptop and its price is 55000
# Phone : 30000
# product who cost is more than 2000 is Phone and its price is 30000
