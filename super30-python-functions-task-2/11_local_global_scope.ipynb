# %%
#Demonstrate Local and Global Scope 
message = "This is a global variable"

def show_message():
    message = "This is a local variable of function"
    print("Inside function:", message)


print("Outside function:", message)

show_message()

print("Outside function call again:", message)
# Out:
# Outside function: This is a global variable
# Inside function: This is a local variable of function
# Outside function call again: This is a global variable
