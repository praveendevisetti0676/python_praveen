# %%
# Nested List Challenge
students = [
    ["Rahul", 21, "Python"],
    ["Priya", 22, "Data Science"],
    ["Aman", 20, "Machine Learning"]
]
#1 Print the complete list 
print("Complete List of Students:", students)
#2 Print Rahul's name
print("Rahul's Name:", students[0][0])
#3 Print Priya's age
print("Priya's Age:", students[1][1])
#4 Print Aman's course
print("Aman's Course:", students[2][2])
#5 Print the complete record of Priya
print("Priya's Complete Record:", students[1])
#6 change Rahul's course to "AI"
students[0][2] = "AI"
print("Updated List of Students:", students)
#7 Add another student record manually
students.append(["Sneha", 21, "Web Development"])
print("List of Students after adding Sneha:", students)
#8 Print the updated nested list
print("Updated Nested List:", students)
# Out:
# Complete List of Students: [['Rahul', 21, 'Python'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning']]
# Rahul's Name: Rahul
# Priya's Age: 22
# Aman's Course: Machine Learning
# Priya's Complete Record: ['Priya', 22, 'Data Science']
# Updated List of Students: [['Rahul', 21, 'AI'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning']]
# List of Students after adding Sneha: [['Rahul', 21, 'AI'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning'], ['Sneha', 21, 'Web Development']]
# Updated Nested List: [['Rahul', 21, 'AI'], ['Priya', 22, 'Data Science'], ['Aman', 20, 'Machine Learning'], ['Sneha', 21, 'Web Development']]
