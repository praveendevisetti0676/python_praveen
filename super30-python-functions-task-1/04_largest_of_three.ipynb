# %%
#Find Largest of Three Numbers using functions
def find_largest(num1, num2, num3):
    """Return the largest of three numbers without using max()."""
    if num1 >= num2 and num1 >= num3:
        return num1
    elif num2 >= num1 and num2 >= num3:
        return num2
    else:
        return num3
    
input_numbers = input("Enter three numbers separated by spaces: ")
num1, num2, num3 = map(int, input_numbers.split())
largest = find_largest(num1, num2, num3)
print(f"The largest number among {num1}, {num2}, and {num3} is: {largest}")
# Out:
# The largest number among 15, 25, and 65 is: 65
