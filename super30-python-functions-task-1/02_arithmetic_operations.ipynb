# %%
#Arithmetic Operations Using Functions 
def add(x, y):  
    """Return the sum of two numbers."""
    return x + y
def subtract(x, y): 
    """Return the difference between two numbers."""
    return x - y
def multiply(x, y): 
     """Return the product of two numbers."""
    return x * y
def divide(x, y): 
    """Return the quotient of two numbers."""
    if y == 0:
        return "Error! Division by zero."
    else:
        return x / y        

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))   

sum=add(num1, num2)
print("The sum of {0} and {1} is: {2}".format(num1, num2, sum))
difference=subtract(num1, num2)
print("The difference of {0} and {1} is: {2}".format(num1, num2, difference))
product=multiply(num1, num2)
print("The product of {0} and {1} is: {2}".format(num1, num2, product))
quotient=divide(num1, num2)
print("The quotient of {0} and {1} is: {2}".format(num1, num2, quotient))
# Out:
# The sum of 25.0 and 40.0 is: 65.0
# The difference of 25.0 and 40.0 is: -15.0
# The product of 25.0 and 40.0 is: 1000.0
# The quotient of 25.0 and 40.0 is: 0.625
