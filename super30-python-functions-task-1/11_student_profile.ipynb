# %%
# Student Profile Using Positional & Keyword Arguments 
def student_profile(name, age, course):
    return f"Name: {name}\nAge: {age}\nCourse: {course}"


# Positional arguments
print("--- Positional Arguments ---")
print(student_profile(22,"Rahul", "Data Science"))


# Keyword arguments
print("\n--- Keyword Arguments ---")
print(
    student_profile(
        course="Python Programming",
        age=21,
        name="Priya"
    )
)
# Out:
# --- Positional Arguments ---
# Name: 22
# Age: Rahul
# Course: Data Science
#
# --- Keyword Arguments ---
# Name: Priya
# Age: 21
# Course: Python Programming
