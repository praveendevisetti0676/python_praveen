# %%
def student_profile(name, age, course):
    """Return a formatted student profile."""
    
    profile = f"Name : {name}\nAge : {age}\nCourse : {course}"
    
    return profile


# Positional arguments
profile1 = student_profile("Rahul", 30, "Python")
print(profile1)


# Keyword arguments
profile2 = student_profile(
    name="Sunil",
    age=30,
    course="Python"
)
print(profile2)

student_profile("Aman", 30, "Python")



student_profile(
    name="Praveen",
    age=30,
    course="Python"
)
# Out:
# Name : Rahul
# Age : 30
# Course : Python
# Name : Sunil
# Age : 30
# Course : Python
# 'Name : Praveen\nAge : 30\nCourse : Python'
