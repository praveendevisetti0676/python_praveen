# %%
#Add Two Numbers Using Function 
def add(a, b): 
    """Return the sum of two numbers."""
    return a + b

# Example usage
result = add_two_numbers(7, 80)
print("The sum is:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3     """Return the sum of two numbers."""
#       4     return a + b
#       5
#       6 # Example usage
# ----> 7 result = add_two_numbers(7, 80)
#       8 print("The sum is:", result)
#
# NameError: name 'add_two_numbers' is not defined
