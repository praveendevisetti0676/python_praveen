# %%
#Reverse an Integer 
num = int(input("Enter a number: "))
input_num = num
reverse = 0 
while num > 0:
    digit = num % 10
    reverse = (reverse * 10) + digit
    num //= 10
print("Reversed number: of ", input_num, "is", reverse)
# Out:
# Reversed number: of  9874 is 4789
