# %%
text = input("Enter a string: ")
# Count the frequency of every character in a string without using Counter.
frequency = {}
for c in text:
    if c in frequency: i
        frequency[c] += 1 
    else:
        frequency[c] = 1 

for char, count in frequency.items():
    print(f"The frequency of '{char}' in the string is: {count}")
# Out:
# The frequency of 'm' in the string is: 1
# The frequency of 'i' in the string is: 4
# The frequency of 's' in the string is: 4
# The frequency of 'p' in the string is: 1
